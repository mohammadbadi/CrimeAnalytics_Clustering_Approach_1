# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadbadi/Clustering_FE_MCA/blob/main/Code%20Sections/5.8%20Summary%20Table%20of%20Clustering%20Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **5.8 Summary Table of Clustering Models - Approach 3**

# %%
import warnings                                                                   # Import necessary libraries
import pandas as pd
import asyncio
# !pip install dataframe_image -qqq
import dataframe_image as dfi
from IPython.display import display, HTML
from google.colab import files

print("\n\n")
warnings.filterwarnings("ignore", category=DeprecationWarning)                    # Ignore Deprecation Warnings
warnings.filterwarnings("ignore", category=FutureWarning)                         # Ignore future warnings

url = "https://raw.githubusercontent.com/mohammadbadi/Clustering_FE_MCA/refs/heads/main/Output_CSV/Feature_Combo_New_Results.csv"  # Load results of all Clustering Models from Approach 3
data = pd.read_csv(url)

metrics = [                                                                       # Define the metrics to evaluate
    'KMeans Silhouette Score',
    'KMeans Calinski-Harabasz Score',
    'DBSCAN Silhouette Score',
    'KMeans Davies-Bouldin Index',
    'DBSCAN Davies-Bouldin Index'
]

top_results = {}                                                                  # Initialize a dictionary to store top results and their counts
feature_set_summary = {}

for metric in metrics:                                                            # Iterate through the top 100 rows for each metric and store occurrences
    if metric in data.columns:
        if 'Davies-Bouldin' in metric:                                            # For Davies-Bouldin Index, we want the lowest values
            top_rows = data.nsmallest(100, metric)
        else:
            top_rows = data.nlargest(100, metric)
        top_results[metric] = top_rows                                            # Store top rows in a dictionary
        for _, row in top_rows.iterrows():                                        # Iterate through the top rows to count occurrences of Feature Sets and track where they were found
            feature_set = row['Features']                                         # Updated column name
            if feature_set not in feature_set_summary:
                feature_set_summary[feature_set] = {
                    'Count': 0,
                    'Found In': []
                }
            feature_set_summary[feature_set]['Count'] += 1
            feature_set_summary[feature_set]['Found In'].append(metric)

summary_df = pd.DataFrame.from_dict(feature_set_summary, orient='index')          # Create a summary of most repeated feature sets
summary_df.reset_index(inplace=True)
summary_df.columns = ['Features', 'Count', 'Found In']                            # Updated column name
summary_df.sort_values(by='Count', ascending=False, inplace=True)                 # Sort by Count in descending order
final_metrics_df = pd.DataFrame(columns=['Set Number', 'Features', 'Count', *metrics])  # Prepare the final metrics DataFrame

for index, row in summary_df.iterrows():
    feature_set_name = row['Features']
    metrics_row = data[data['Features'] == feature_set_name]
    if not metrics_row.empty:
        new_row = {
            'Set Number': metrics_row['Set Number'].values[0],                    # Fetch Set Number from CSV
            'Features': feature_set_name,
            'Count': row['Count'],
            **{metric: metrics_row[metric].values[0] for metric in metrics}
        }
        if final_metrics_df.empty:                                                # Handle empty DataFrame scenario properly before concatenation
            final_metrics_df = pd.DataFrame([new_row])                            # Append the new row to the final metrics DataFrame
        else:
            final_metrics_df = pd.concat([final_metrics_df, pd.DataFrame([new_row])], ignore_index=True)

final_metrics_df.sort_values(by='Count', ascending=False, inplace=True)           # Sort the final metrics DataFrame by Count

desired_order = ['Set Number', 'Features', 'Count',
                 'KMeans Silhouette Score', 'KMeans Calinski-Harabasz Score', 'KMeans Davies-Bouldin Index',
                 'DBSCAN Silhouette Score', 'DBSCAN Davies-Bouldin Index']
final_metrics_df = final_metrics_df[desired_order]                                # Reorder columns as requested

                                                                                  # Create Table: Top 7 Models in Approach 3
                                                                                  # Top 3 models based on highest KMeans Silhouette Score
top3_kmeans = final_metrics_df.nlargest(3, 'KMeans Silhouette Score')
                                                                                  # Top 4 models based on highest DBSCAN Silhouette Score
top4_dbscan = final_metrics_df.nlargest(4, 'DBSCAN Silhouette Score')
                                                                                  # Combine them into one table; drop duplicates if any
top7_df = pd.concat([top3_kmeans, top4_dbscan]).drop_duplicates().reset_index(drop=True)
top7_df = top7_df[desired_order]                                                  # Reorder columns in the Top 7 table

                                                                                  # Create a styled table for Top 7 Models
styled_top7 = top7_df.style.set_caption("<h3 style='color: navy; text-align: center;'>Top 7 Models in Approach 3</h3>")\
    .format({
        'KMeans Silhouette Score': '{:.2f}',                                      # 2 decimals for Silhouette
        'DBSCAN Silhouette Score': '{:.2f}',                                      # 2 decimals for Silhouette
        'KMeans Davies-Bouldin Index': '{:.2f}',                                  # 2 decimals for DBI
        'DBSCAN Davies-Bouldin Index': '{:.2f}',                                  # 2 decimals for DBI
        'KMeans Calinski-Harabasz Score': '{:.0f}'                                # no decimals for CHI
    })\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#4CAF50'),
                                     ('color', 'white'),
                                     ('font-weight', 'bold'),
                                     ('text-align', 'center'),
                                     ('border', '1px solid black')]},
        {'selector': 'td', 'props': [('padding', '10px'),
                                     ('text-align', 'center'),
                                     ('border', '1px solid black')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse')]}
    ])\
    .set_properties(**{'border': '1px solid black'})

display(HTML("<h2 style='color: green; font-size: 20px;'><b>Top 7 Models in Approach 3:</b></h2>"))
display(styled_top7)

                                                                                  # Export and download the Top 7 Models table as a PNG image
dfi.export(top7_df, 'Top 7 models in Approach 3.png', table_conversion='matplotlib', max_rows=-1)
files.download('Top 7 models in Approach 3.png')

                                                                                  #Create Table - display Outputs of ALL Clustering Models in Approach 3
                                                                                  # Define a helper function to highlight the top 5 values correctly
def highlight_top5(s, ascending=True):
    sorted_vals = s.sort_values(ascending=ascending).dropna()                     # Sort the values and remove NaN
    top5_vals = sorted_vals.head(5).unique()                                      # Get the top 5 unique values
    return ['background-color: lightgreen' if x in top5_vals else '' for x in s]  # Return styling only for values in top5_vals

                                                                                  # Apply highlighting with correct order:
                                                                                  # For silhouette and Calinski-Harabasz, higher is better (descending sort)
                                                                                  # For Davies-Bouldin Index, lower is better (ascending sort)
styled_table = final_metrics_df.style.apply(lambda s: highlight_top5(s, ascending=False), subset=['KMeans Silhouette Score'])\
    .apply(lambda s: highlight_top5(s, ascending=False), subset=['DBSCAN Silhouette Score'])\
    .apply(lambda s: highlight_top5(s, ascending=True), subset=['KMeans Davies-Bouldin Index'])\
    .apply(lambda s: highlight_top5(s, ascending=True), subset=['DBSCAN Davies-Bouldin Index'])\
    .apply(lambda s: highlight_top5(s, ascending=False), subset=['KMeans Calinski-Harabasz Score'])\
    .format({
        'KMeans Silhouette Score': '{:.2f}',                                      # 2 decimals for Silhouette
        'DBSCAN Silhouette Score': '{:.2f}',                                      # 2 decimals for Silhouette
        'KMeans Davies-Bouldin Index': '{:.2f}',                                  # 2 decimals for DBI
        'DBSCAN Davies-Bouldin Index': '{:.2f}',                                  # 2 decimals for DBI
        'KMeans Calinski-Harabasz Score': '{:.0f}'                                # no decimals for CHI
    })\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#4CAF50'),
                                     ('color', 'white'),
                                     ('font-weight', 'bold'),
                                     ('text-align', 'center'),
                                     ('border', '1px solid black')]},             # Center-align and add black borders to headers
        {'selector': 'td', 'props': [('padding', '10px'),
                                     ('text-align', 'center'),
                                     ('border', '1px solid black')]},             # Center-align and add black borders to all cells
        {'selector': 'table', 'props': [('border-collapse', 'collapse')]}         # Ensure border styling applies correctly
    ])\
    .set_properties(**{'border': '1px solid black'})\
    .set_caption("<h3 style='color: navy; text-align: center;'>📊 Metrics Summary Table</h3>")

display(HTML("<h2 style='color: green; font-size: 20px;'><b>Styled Metrics Summary Table:</b></h2>"))
display(styled_table)

styled_table.data.to_excel('metrics_summary_table.xlsx', index=False)             # Save the styled table to an Excel file

display(HTML("""
    <p style="color: darkblue; font-size: 18px; font-weight: bold;">
         Metrics summary table has been saved to <span style="color: green;">'metrics_summary_table.xlsx'</span>.
    </p>
"""))
dfi.export(styled_table.data, 'metrics_summary_table.png', table_conversion='matplotlib', max_rows=-1)
files.download('metrics_summary_table.png')                                       # Download the results in PNG file
files.download('metrics_summary_table.xlsx')                                      # Download the results in Excel File
# Out:
# <h2 style='color: green; font-size: 20px;'><b>Top 7 Models in Approach 3:</b></h2>
# <style type="text/css">
# #T_ab158 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_ab158 td {
#   padding: 10px;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_ab158 table {
#   border-collapse: collapse;
# }
# #T_ab158_row0_col0, #T_ab158_row0_col1, #T_ab158_row0_col2, #T_ab158_row0_col3, #T_ab158_row0_col4, #T_ab158_row0_col5, #T_ab158_row0_col6, #T_ab158_row0_col7, #T_ab158_row1_col0, #T_ab158_row1_col1, #T_ab158_row1_col2, #T_ab158_row1_col3, #T_ab158_row1_col4, #T_ab158_row1_col5, #T_ab158_row1_col6, #T_ab158_row1_col7, #T_ab158_row2_col0, #T_ab158_row2_col1, #T_ab158_row2_col2, #T_ab158_row2_col3, #T_ab158_row2_col4, #T_ab158_row2_col5, #T_ab158_row2_col6, #T_ab158_row2_col7, #T_ab158_row3_col0, #T_ab158_row3_col1, #T_ab158_row3_col2, #T_ab158_row3_col3, #T_ab158_row3_col4, #T_ab158_row3_col5, #T_ab158_row3_col6, #T_ab158_row3_col7, #T_ab158_row4_col0, #T_ab158_row4_col1, #T_ab158_row4_col2, #T_ab158_row4_col3, #T_ab158_row4_col4, #T_ab158_row4_col5, #T_ab158_row4_col6, #T_ab158_row4_col7, #T_ab158_row5_col0, #T_ab158_row5_col1, #T_ab158_row5_col2, #T_ab158_row5_col3, #T_ab158_row5_col4, #T_ab158_row5_col5, #T_ab158_row5_col6, #T_ab158_row5_col7, #T_ab158_row6_col0, #T_ab158_row6_col1, #T_ab158_row6_col2, #T_ab158_row6_col3, #T_ab158_row6_col4, #T_ab158_row6_col5, #T_ab158_row6_col6, #T_ab158_row6_col7 {
#   border: 1px solid black;
# }
# </style>
# <table id="T_ab158" class="dataframe">
#   <caption><h3 style='color: navy; text-align: center;'>Top 7 Models in Approach 3</h3></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab158_level0_col0" class="col_heading level0 col0" >Set Number</th>
#       <th id="T_ab158_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_ab158_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_ab158_level0_col3" class="col_heading level0 col3" >KMeans Silhouette Score</th>
#       <th id="T_ab158_level0_col4" class="col_heading level0 col4" >KMeans Calinski-Harabasz Score</th>
#       <th id="T_ab158_level0_col5" class="col_heading level0 col5" >KMeans Davies-Bouldin Index</th>
#       <th id="T_ab158_level0_col6" class="col_heading level0 col6" >DBSCAN Silhouette Score</th>
#       <th id="T_ab158_level0_col7" class="col_heading level0 col7" >DBSCAN Davies-Bouldin Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab158_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab158_row0_col0" class="data row0 col0" >557</td>
#       <td id="T_ab158_row0_col1" class="data row0 col1" >['OCC_DOY', 'OCC_MONTH_Num', 'HOOD_Freq', 'LOCATION_Freq']</td>
#       <td id="T_ab158_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_ab158_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_ab158_row0_col4" class="data row0 col4" >4409</td>
#       <td id="T_ab158_row0_col5" class="data row0 col5" >0.72</td>
#       <td id="T_ab158_row0_col6" class="data row0 col6" >0.51</td>
#       <td id="T_ab158_row0_col7" class="data row0 col7" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab158_row1_col0" class="data row1 col0" >562</td>
#       <td id="T_ab158_row1_col1" class="data row1 col1" >['OCC_DOY', 'OCC_MONTH_Num', 'DIV_HOOD_Hier', 'Loca_Premi_Freq']</td>
#       <td id="T_ab158_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_ab158_row1_col3" class="data row1 col3" >0.49</td>
#       <td id="T_ab158_row1_col4" class="data row1 col4" >4369</td>
#       <td id="T_ab158_row1_col5" class="data row1 col5" >0.73</td>
#       <td id="T_ab158_row1_col6" class="data row1 col6" >0.52</td>
#       <td id="T_ab158_row1_col7" class="data row1 col7" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab158_row2_col0" class="data row2 col0" >561</td>
#       <td id="T_ab158_row2_col1" class="data row2 col1" >['OCC_DOY', 'OCC_MONTH_Num', 'DIV_HOOD_Hier', 'PREMISES_Freq']</td>
#       <td id="T_ab158_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_ab158_row2_col3" class="data row2 col3" >0.48</td>
#       <td id="T_ab158_row2_col4" class="data row2 col4" >4388</td>
#       <td id="T_ab158_row2_col5" class="data row2 col5" >0.73</td>
#       <td id="T_ab158_row2_col6" class="data row2 col6" >0.52</td>
#       <td id="T_ab158_row2_col7" class="data row2 col7" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ab158_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_ab158_row3_col1" class="data row3 col1" >['LONG_WGS84', 'LAT_WGS84', 'DIV_HOOD_Hier', 'LOCATION_Freq']</td>
#       <td id="T_ab158_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_ab158_row3_col3" class="data row3 col3" >0.37</td>
#       <td id="T_ab158_row3_col4" class="data row3 col4" >3318</td>
#       <td id="T_ab158_row3_col5" class="data row3 col5" >0.96</td>
#       <td id="T_ab158_row3_col6" class="data row3 col6" >0.53</td>
#       <td id="T_ab158_row3_col7" class="data row3 col7" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ab158_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_ab158_row4_col1" class="data row4 col1" >['LONG_WGS84', 'LAT_WGS84', 'DIV_HOOD_Hier', 'Loca_Premi_Freq']</td>
#       <td id="T_ab158_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_ab158_row4_col3" class="data row4 col3" >0.40</td>
#       <td id="T_ab158_row4_col4" class="data row4 col4" >3252</td>
#       <td id="T_ab158_row4_col5" class="data row4 col5" >0.89</td>
#       <td id="T_ab158_row4_col6" class="data row4 col6" >0.53</td>
#       <td id="T_ab158_row4_col7" class="data row4 col7" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ab158_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_ab158_row5_col1" class="data row5 col1" >['LONG_WGS84', 'LAT_WGS84', 'DIV_HOOD_Hier', 'PREMISES_Freq']</td>
#       <td id="T_ab158_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_ab158_row5_col3" class="data row5 col3" >0.39</td>
#       <td id="T_ab158_row5_col4" class="data row5 col4" >3251</td>
#       <td id="T_ab158_row5_col5" class="data row5 col5" >0.89</td>
#       <td id="T_ab158_row5_col6" class="data row5 col6" >0.52</td>
#       <td id="T_ab158_row5_col7" class="data row5 col7" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_ab158_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ab158_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_ab158_row6_col1" class="data row6 col1" >['LONG_WGS84', 'LAT_WGS84', 'HOOD_Freq', 'LOCATION_Freq']</td>
#       <td id="T_ab158_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_ab158_row6_col3" class="data row6 col3" >0.39</td>
#       <td id="T_ab158_row6_col4" class="data row6 col4" >3285</td>
#       <td id="T_ab158_row6_col5" class="data row6 col5" >0.87</td>
#       <td id="T_ab158_row6_col6" class="data row6 col6" >0.52</td>
#       <td id="T_ab158_row6_col7" class="data row6 col7" >0.63</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style='color: green; font-size: 20px;'><b>Styled Metrics Summary Table:</b></h2>
# <style type="text/css">
# #T_1296f th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_1296f td {
#   padding: 10px;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_1296f table {
#   border-collapse: collapse;
# }
# #T_1296f_row0_col0, #T_1296f_row0_col1, #T_1296f_row0_col2, #T_1296f_row0_col3, #T_1296f_row0_col4, #T_1296f_row0_col5, #T_1296f_row0_col6, #T_1296f_row0_col7, #T_1296f_row1_col0, #T_1296f_row1_col1, #T_1296f_row1_col2, #T_1296f_row1_col3, #T_1296f_row1_col4, #T_1296f_row1_col5, #T_1296f_row1_col7, #T_1296f_row2_col0, #T_1296f_row2_col1, #T_1296f_row2_col2, #T_1296f_row2_col3, #T_1296f_row2_col4, #T_1296f_row2_col5, #T_1296f_row2_col7, #T_1296f_row3_col0, #T_1296f_row3_col1, #T_1296f_row3_col2, #T_1296f_row3_col3, #T_1296f_row3_col4, #T_1296f_row3_col5, #T_1296f_row3_col7, #T_1296f_row4_col0, #T_1296f_row4_col1, #T_1296f_row4_col2, #T_1296f_row4_col3, #T_1296f_row4_col4, #T_1296f_row4_col5, #T_1296f_row4_col6, #T_1296f_row4_col7, #T_1296f_row5_col0, #T_1296f_row5_col1, #T_1296f_row5_col2, #T_1296f_row5_col3, #T_1296f_row5_col4, #T_1296f_row5_col5, #T_1296f_row5_col6, #T_1296f_row5_col7, #T_1296f_row6_col0, #T_1296f_row6_col1, #T_1296f_row6_col2, #T_1296f_row6_col3, #T_1296f_row6_col4, #T_1296f_row6_col5, #T_1296f_row6_col7, #T_1296f_row7_col0, #T_1296f_row7_col1, #T_1296f_row7_col2, #T_1296f_row7_col3, #T_1296f_row7_col4, #T_1296f_row7_col5, #T_1296f_row7_col7, #T_1296f_row8_col0, #T_1296f_row8_col1, #T_1296f_row8_col2, #T_1296f_row8_col3, #T_1296f_row8_col4, #T_1296f_row8_col5, #T_1296f_row8_col6, #T_1296f_row8_col7, #T_1296f_row9_col0, #T_1296f_row9_col1, #T_1296f_row9_col2, #T_1296f_row9_col3, #T_1296f_row9_col4, #T_1296f_row9_col5, #T_1296f_row9_col6, #T_1296f_row9_col7, #T_1296f_row10_col0, #T_1296f_row10_col1, #T_1296f_row10_col2, #T_1296f_row10_col3, #T_1296f_row10_col4, #T_1296f_row10_col5, #T_1296f_row10_col6, #T_1296f_row10_col7, #T_1296f_row11_col0, #T_1296f_row11_col1, #T_1296f_row11_col2, #T_1296f_row11_col3, #T_1296f_row11_col4, #T_1296f_row11_col5, #T_1296f_row11_col6, #T_1296f_row11_col7, #T_1296f_row12_col0, #T_1296f_row12_col1, #T_1296f_row12_col2, #T_1296f_row12_col3, #T_1296f_row12_col4, #T_1296f_row12_col5, #T_1296f_row12_col6, #T_1296f_row12_col7, #T_1296f_row13_col0, #T_1296f_row13_col1, #T_1296f_row13_col2, #T_1296f_row13_col3, #T_1296f_row13_col4, #T_1296f_row13_col5, #T_1296f_row13_col6, #T_1296f_row13_col7, #T_1296f_row14_col0, #T_1296f_row14_col1, #T_1296f_row14_col2, #T_1296f_row14_col3, #T_1296f_row14_col4, #T_1296f_row14_col5, #T_1296f_row14_col6, #T_1296f_row14_col7, #T_1296f_row15_col0, #T_1296f_row15_col1, #T_1296f_row15_col2, #T_1296f_row15_col3, #T_1296f_row15_col4, #T_1296f_row15_col5, #T_1296f_row15_col6, #T_1296f_row15_col7, #T_1296f_row16_col0, #T_1296f_row16_col1, #T_1296f_row16_col2, #T_1296f_row16_col3, #T_1296f_row16_col4, #T_1296f_row16_col5, #T_1296f_row16_col6, #T_1296f_row16_col7, #T_1296f_row17_col0, #T_1296f_row17_col1, #T_1296f_row17_col2, #T_1296f_row17_col4, #T_1296f_row17_col6, #T_1296f_row17_col7, #T_1296f_row18_col0, #T_1296f_row18_col1, #T_1296f_row18_col2, #T_1296f_row18_col4, #T_1296f_row18_col6, #T_1296f_row18_col7, #T_1296f_row19_col0, #T_1296f_row19_col1, #T_1296f_row19_col2, #T_1296f_row19_col6, #T_1296f_row19_col7, #T_1296f_row20_col0, #T_1296f_row20_col1, #T_1296f_row20_col2, #T_1296f_row20_col3, #T_1296f_row20_col4, #T_1296f_row20_col5, #T_1296f_row20_col6, #T_1296f_row20_col7, #T_1296f_row21_col0, #T_1296f_row21_col1, #T_1296f_row21_col2, #T_1296f_row21_col3, #T_1296f_row21_col4, #T_1296f_row21_col5, #T_1296f_row21_col6, #T_1296f_row21_col7, #T_1296f_row22_col0, #T_1296f_row22_col1, #T_1296f_row22_col2, #T_1296f_row22_col3, #T_1296f_row22_col4, #T_1296f_row22_col5, #T_1296f_row22_col6, #T_1296f_row22_col7, #T_1296f_row23_col0, #T_1296f_row23_col1, #T_1296f_row23_col2, #T_1296f_row23_col3, #T_1296f_row23_col5, #T_1296f_row23_col6, #T_1296f_row23_col7, #T_1296f_row24_col0, #T_1296f_row24_col1, #T_1296f_row24_col2, #T_1296f_row24_col3, #T_1296f_row24_col5, #T_1296f_row24_col6, #T_1296f_row24_col7, #T_1296f_row25_col0, #T_1296f_row25_col1, #T_1296f_row25_col2, #T_1296f_row25_col3, #T_1296f_row25_col4, #T_1296f_row25_col5, #T_1296f_row25_col6, #T_1296f_row25_col7, # ...
#     <p style="color: darkblue; font-size: 18px; font-weight: bold;">
#          Metrics summary table has been saved to <span style="color: green;">'metrics_summary_table.xlsx'</span>.
#     </p>
