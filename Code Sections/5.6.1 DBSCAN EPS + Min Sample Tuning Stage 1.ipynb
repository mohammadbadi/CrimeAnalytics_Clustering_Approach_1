# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadbadi/Clustering_FE_MCA/blob/main/Code%20Sections/5.6.1%20DBSCAN%20EPS%20%2B%20Min%20Sample%20Tuning%20Stage%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **5.6.1 DBSCAN EPS + Min Sample Tuning: Stage 1 - Coarse Tuning**
# ### **wider jumps of eps and min sample - APPROACH 3**

# %%
import pandas as pd                                                               # Parallel Processing Setup
start_chunk = 16                                                                  # Set these variables for each run. Edit as needed (1-indexed)
num_chunks_to_process = 5                                                         # Edit value to change number of chunks to be processed at 1 go
end_chunk = start_chunk + num_chunks_to_process - 1

feature_df = pd.read_csv("Feature_Combo_All_with_set_number.csv")                 # Load the previously saved feature combinations CSV.

import math                                                                       # Split the list of feature sets into chunks of 143 sets.
all_combinations = feature_df['features'].apply(eval).tolist()                    # Convert string repr back to list
chunk_size = 143
chunks = [all_combinations[i:i + chunk_size] for i in range(0, len(all_combinations), chunk_size)]
total_chunks = len(chunks)

if start_chunk < 1 or start_chunk > total_chunks:
    raise ValueError("start_chunk must be between 1 and total number of chunks")
if end_chunk > total_chunks:
    end_chunk = total_chunks

print(f"Processing chunks from {start_chunk} to {end_chunk} (each with 143 sets)")

url = "https://raw.githubusercontent.com/mohammadbadi/Clustering_FE_MCA/refs/heads/main/Output_CSV/FE_Encoded_New.csv" # URL of the Dataset
data = pd.read_csv(url)                                                           # Load the Dataset
data = data.sample(frac=0.1, random_state=42)                                     # 10% Sample from Dataset

import numpy as np                                                                # STAGE 1 - Coarse Tuning for Selected Chunks
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from google.colab import files

eps_values_coarse = np.array([1, 2, 3, 4, 5])
min_samples_values_coarse = [5, 10, 15]

for chunk_index in range(start_chunk, end_chunk+1):                               # Process each chunk in the specified range.
    chunk = chunks[chunk_index - 1]                                               # converting 1-indexed to 0-indexed
    results = []
    for local_set_number, feature_set in enumerate(chunk, start=1):               # Process each set in the current chunk.
        global_set_number = (chunk_index - 1) * chunk_size + local_set_number     # Compute global set_number for clarity.

        missing_features = [feat for feat in feature_set if feat not in data.columns]
        if missing_features:                                                      # If features are missing, record a row with Nones.
            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": None,
                "best_min_samples": None,
                "best_silhouette_score": None,
                "top10_eps": None,
                "top10_min_samples": None,
                "top10_eps_min": None,
                "top10_eps_max": None,
                "top10_min_samples_min": None,
                "top10_min_samples_max": None
            })
            print(f"Set {global_set_number} evaluated. Missing features: {missing_features}")
            continue

        df_subset = data[feature_set]
        scaler = StandardScaler()
        df_subset = pd.DataFrame(scaler.fit_transform(df_subset), columns=df_subset.columns)

        score_list = []
        for eps in eps_values_coarse:
            for min_samples in min_samples_values_coarse:
                try:
                    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
                    labels = dbscan.fit_predict(df_subset)                        # Only consider valid clustering results (at least 2 clusters and some non-noise labels)
                    if len(set(labels)) > 1 and any(label != -1 for label in labels):
                        score = silhouette_score(df_subset, labels)
                        score_list.append((score, eps, min_samples))
                except Exception:
                    continue

        if score_list:
            score_list.sort(key=lambda x: x[0], reverse=True)
            top_10 = score_list[:10]
            top10_eps = [entry[1] for entry in top_10]
            top10_min_samples = [entry[2] for entry in top_10]
            eps_range = (min(top10_eps), max(top10_eps))
            min_samples_range = (min(top10_min_samples), max(top10_min_samples))
            best_score, best_eps, best_min_samples = top_10[0]

            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": best_eps,
                "best_min_samples": best_min_samples,
                "best_silhouette_score": best_score,
                "top10_eps": str(top10_eps),
                "top10_min_samples": str(top10_min_samples),
                "top10_eps_min": eps_range[0],
                "top10_eps_max": eps_range[1],
                "top10_min_samples_min": min_samples_range[0],
                "top10_min_samples_max": min_samples_range[1]
            })
            print(f"Set {global_set_number} evaluated. Best: (eps: {best_eps}, min_samples: {best_min_samples}), Score: {best_score:.4f}")
        else:
            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": None,
                "best_min_samples": None,
                "best_silhouette_score": None,
                "top10_eps": None,
                "top10_min_samples": None,
                "top10_eps_min": None,
                "top10_eps_max": None,
                "top10_min_samples_min": None,
                "top10_min_samples_max": None
            })
            print(f"Set {global_set_number} evaluated. No valid clustering found.")

    results_df = pd.DataFrame(results)                                            # Save results for the current chunk.
    output_filename = f"DBSCAN_Coarse_Top10_chunk_{chunk_index}.csv"
    results_df.to_csv(output_filename, index=False)
    print(f"Chunk {chunk_index} processed and saved to '{output_filename}'.")
    files.download(output_filename)
# Out:
# Processing chunks from 16 to 20 (each with 143 sets)
# Set 2146 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.1655
# Set 2147 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.0360
# Set 2148 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.0129
# Set 2149 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0016
# Set 2150 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3792
# Set 2151 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3461
# Set 2152 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3461
# Set 2153 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3199
# Set 2154 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3842
# Set 2155 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3508
# Set 2156 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3507
# Set 2157 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3531
# Set 2158 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1515
# Set 2159 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1079
# Set 2160 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.0617
# Set 2161 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1198
# Set 2162 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0284
# Set 2163 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1268
# Set 2164 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1581
# Set 2165 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1703
# Set 2166 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3553
# Set 2167 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3276
# Set 2168 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3276
# Set 2169 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3299
# Set 2170 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3597
# Set 2171 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3317
# Set 2172 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3318
# Set 2173 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3339
# Set 2174 evaluated. No valid clustering found.
# Set 2175 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1248
# Set 2176 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1188
# Set 2177 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1112
# Set 2178 evaluated. No valid clustering found.
# Set 2179 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1108
# Set 2180 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0854
# Set 2181 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0847
# Set 2182 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.4320
# Set 2183 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3880
# Set 2184 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3876
# Set 2185 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3899
# Set 2186 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.4377
# Set 2187 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3933
# Set 2188 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3928
# Set 2189 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3951
# Set 2190 evaluated. No valid clustering found.
# Set 2191 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0852
# Set 2192 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0901
# Set 2193 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0820
# Set 2194 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1175
# Set 2195 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0141
# Set 2196 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0224
# Set 2197 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0214
# Set 2198 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.3868
# Set 2199 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3518
# Set 2200 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3517
# Set 2201 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3261
# Set 2202 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.3918
# Set 2203 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3565
# Set 2204 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3564
# Set 2205 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3586
# Set 2206 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.2038
# Set 2207 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0483
# Set 2208 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0275
# Set 2209 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0244
# Set 2210 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.1534
# Set 2211 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.0951
# Set 2212 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1013
# Set 2213 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1472
# Set 2214 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3610
# Set 2215 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3320
# Set 2216 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3319
# Set 2217 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3341
# Set 2218 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3654
# Set 2219 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3362
# Set 2220 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3361
# Set 2221 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3382
# Set 2222 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.2554
# Set 2223 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1505
# Set 2224 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1407
# Set 2225 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.
evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3829
# Set 2615 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3483
# Set 2616 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3482
# Set 2617 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.3182
# Set 2618 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3882
# Set 2619 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3532
# Set 2620 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3531
# Set 2621 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.3234
# Set 2622 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.1531
# Set 2623 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0394
# Set 2624 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0199
# Set 2625 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0321
# Set 2626 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1418
# Set 2627 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1325
# Set 2628 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1014
# Set 2629 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1137
# Set 2630 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3476
# Set 2631 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3194
# Set 2632 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3195
# Set 2633 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2887
# Set 2634 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3524
# Set 2635 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3239
# Set 2636 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3239
# Set 2637 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3262
# Set 2638 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1347
# Set 2639 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2356
# Set 2640 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1898
# Set 2641 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1347
# Set 2642 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0234
# Set 2643 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1508
# Set 2644 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1717
# Set 2645 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1738
# Set 2646 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3284
# Set 2647 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3045
# Set 2648 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3046
# Set 2649 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3067
# Set 2650 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3325
# Set 2651 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3084
# Set 2652 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3085
# Set 2653 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3106
# Set 2654 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.2152
# Set 2655 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1227
# Set 2656 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1146
# Set 2657 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1040
# Set 2658 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1228
# Set 2659 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0251
# Set 2660 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0639
# Set 2661 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0586
# Set 2662 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3817
# Set 2663 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3474
# Set 2664 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3473
# Set 2665 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3495
# Set 2666 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3870
# Set 2667 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3524
# Set 2668 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3522
# Set 2669 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3544
# Set 2670 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1763
# Set 2671 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0405
# Set 2672 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0450
# Set 2673 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0344
# Set 2674 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1308
# Set 2675 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.0757
# Set 2676 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2075
# Set 2677 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1994
# Set 2678 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3467
# Set 2679 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3187
# Set 2680 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3187
# Set 2681 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2936
# Set 2682 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3515
# Set 2683 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3232
# Set 2684 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3232
# Set 2685 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3254
# Set 2686 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0748
# Set 2687 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1900
# Set 2688 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1548
# Set 2689 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.2070
# Set 2690 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0054
# Set 2691 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.2486
# Set 2692 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1955
# Set 2693 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1870
# Set 2694 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3277
# Set 2695 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3039
# Set 2696 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3040
# Set 2697 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3061
# Set 2698 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3319
# Set 2699 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3079
# Set 2700 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3079
# Set 2701 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3100
# Set 2702 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1762
# Set 2703 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0072
# Set 2704 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0236
# Set 2705 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0341
# Set 2706 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0719
# Set 2707 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1881
# Set 2708 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2254
# Set 2709 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2209
# Set 2710 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3441
# Set 2711 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2934
# Set 2712 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2916
# Set 2713 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2927
# Set 2714 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3491
# Set 2715 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2981
# Set 2716 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2962
# Set 2717 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2975
# Chunk 19 processed and saved to 'DBSCAN_Coarse_Top10_chunk_19.csv'.
# Set 2718 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.1186
# Set 2719 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1558
# Set 2720 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.1657
# Set 2721 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.1560
# Set 2722 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.2386
# Set 2723 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1734
# Set 2724 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1720
# Set 2725 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1625
# Set 2726 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3160
# Set 2727 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2691
# Set 2728 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2694
# Set 2729 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2681
# Set 2730 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3205
# Set 2731 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2971
# Set 2732 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2972
# Set 2733 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2994
# Set 2734 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2860
# Set 2735 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1985
# Set 2736 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1873
# Set 2737 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1935
# Set 2738 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2752
# Set 2739 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1505
# Set 2740 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1533
# Set 2741 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1449
# Set 2742 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3015
# Set 2743 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2815
# Set 2744 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2817
# Set 2745 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2838
# Set 2746 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3055
# Set 2747 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2853
# Set 2748 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2854
# Set 2749 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2875
# Chunk 20 processed and saved to 'DBSCAN_Coarse_Top10_chunk_20.csv'.
